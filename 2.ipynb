# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Meenakshi/Downloads/ML/temperatures - temperatures.csv")

# %%
x=df['YEAR']
y=df['ANNUAL']
plt.scatter(x=df['YEAR'],y=df['ANNUAL'])

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (117,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()

# %%
reg=model.fit(x_train.reshape(-1,1),y_train)

# %%
ypred=model.predict(x_test.reshape(-1,1))

# %%
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_test, ypred, color='red', linewidth=3)
